# %%
## SOPbot setup and initial testing ##

# %%
## install dependencies ##
# %pip install -r ../requirements.txt
# Out:
# Requirement already satisfied: python-dotenv==1.0.0 in c:\users\spdransf\pycharmprojects\urogroup\.venv\lib\site-packages (from -r ../requirements.txt (line 1)) (1.0.0)
# Requirement already satisfied: pypdf2==3.0.1 in c:\users\spdransf\pycharmprojects\urogroup\.venv\lib\site-packages (from -r ../requirements.txt (line 2)) (3.0.1)
# Requirement already satisfied: openai==1.12.0 in c:\users\spdransf\pycharmprojects\urogroup\.venv\lib\site-packages (from -r ../requirements.txt (line 3)) (1.12.0)
# Requirement already satisfied: azure-search-documents==11.4.0 in c:\users\spdransf\pycharmprojects\urogroup\.venv\lib\site-packages (from -r ../requirements.txt (line 4)) (11.4.0)
# Requirement already satisfied: tiktoken==0.5.2 in c:\users\spdransf\pycharmprojects\urogroup\.venv\lib\site-packages (from -r ../requirements.txt (line 5)) (0.5.2)
# Requirement already satisfied: streamlit==1.31.0 in c:\users\spdransf\pycharmprojects\urogroup\.venv\lib\site-packages (from -r ../requirements.txt (line 6)) (1.31.0)
# Requirement already satisfied: pandas==2.2.0 in c:\users\spdransf\pycharmprojects\urogroup\.venv\lib\site-packages (from -r ../requirements.txt (line 7)) (2.2.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\spdransf\pycharmprojects\urogroup\.venv\lib\site-packages (from openai==1.12.0->-r ../requirements.txt (line 3)) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\spdransf\pycharmprojects\urogroup\.venv\lib\site-packages (from openai==1.12.0->-r ../requirements.txt (line 3)) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\spdransf\pycharmprojects\urogroup\.venv\lib\site-packages (from openai==1.12.0->-r ../requirements.txt (line 3)) (0.27.2)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\spdransf\pycharmprojects\urogroup\.venv\lib\site-packages (from openai==1.12.0->-r ../requirements.txt (line 3)) (2.12.5)
# Requirement already satisfied: sniffio in c:\users\spdransf\pycharmprojects\urogroup\.venv\lib\site-packages (from openai==1.12.0->-r ../requirements.txt (line 3)) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\spdransf\pycharmprojects\urogroup\.venv\lib\site-packages (from openai==1.12.0->-r ../requirements.txt (line 3)) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.7 in c:\users\spdransf\pycharmprojects\urogroup\.venv\lib\site-packages (from openai==1.12.0->-r ../requirements.txt (line 3)) (4.15.0)
# Requirement already satisfied: azure-core<2.0.0,>=1.28.0 in c:\users\spdransf\pycharmprojects\urogroup\.venv\lib\site-packages (from azure-search-documents==11.4.0->-r ../requirements.txt (line 4)) (1.37.0)
# Requirement already satisfied: azure-common~=1.1 in c:\users\spdransf\pycharmprojects\urogroup\.venv\lib\site-packages (from azure-search-documents==11.4.0->-r ../requirements.txt (line 4)) (1.1.28)
# Requirement already satisfied: isodate>=0.6.0 in c:\users\spdransf\pycharmprojects\urogroup\.venv\lib\site-packages (from azure-search-documents==11.4.0->-r ../requirements.txt (line 4)) (0.7.2)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\spdransf\pycharmprojects\urogroup\.venv\lib\site-packages (from tiktoken==0.5.2->-r ../requirements.txt (line 5)) (2025.11.3)
# Requirement already satisfied: requests>=2.26.0 in c:\users\spdransf\pycharmprojects\urogroup\.venv\lib\site-packages (from tiktoken==0.5.2->-r ../requirements.txt (line 5)) (2.32.5)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\spdransf\pycharmprojects\urogroup\.venv\lib\site-packages (from streamlit==1.31.0->-r ../requirements.txt (line 6)) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\spdransf\pycharmprojects\urogroup\.venv\lib\site-packages (from streamlit==1.31.0->-r ../requirements.txt (line 6)) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\spdransf\pycharmprojects\urogroup\.venv\lib\site-packages (from streamlit==1.31.0->-r ../requirements.txt (line 6)) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in c:\users\spdransf\pycharmprojects\urogroup\.venv\lib\site-packages (from streamlit==1.31.0->-r ../requirements.txt (line 6)) (8.3.1)
# Requirement already satisfied: importlib-metadata<8,>=1.4 in c:\users\spdransf\pycharmprojects\urogroup\.venv\lib\site-packages (from streamlit==1.31.0->-r ../requirements.txt (line 6)) (7.2.1)
# Requirement already satisfied: numpy<2,>=1.19.3 in c:\users\spdransf\pycharmprojects\urogroup\.venv\lib\site-packages (from streamlit==1.31.0->-r ../requirements.txt (line 6)) (1.26.4)
# Requirement already satisfied: packaging<24,>=16.8 in c:\users\spdransf\pycharmprojects\urogroup\.venv\lib\site-packages (from streamlit==1.31.0->-r ../requirements.txt (line 6)) (23.2)
# Requirement already satisfied: pillow<11,>=7.1.0 in c:\users\spdransf\pycharmprojects\urogroup\.venv\lib\site-packages (from streamlit==1.31.0->-r ../requirements.txt (line 6)) (10.4.0)
# Requirement already satisfied: protobuf<5,>=3.20 in c:\users\spdransf\pycharmprojects\urogroup\.venv\lib\site-packages (from streamlit==1.31.0->-r ../requirements.txt (line 6)) (4.25.8)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\spdransf\pycharmprojects\urogroup\.venv\lib\site-packages (from streamlit==1.31.0->-r ../requirements.txt (line 6)) (22.0.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.3 in c:\users\spdransf\pycharmprojects\urogroup\.venv\lib\site-packages (from streamlit==1.31.0->-r ../requirements.txt (line 6)) (2.9.0.post0)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\spdransf\pycharmprojects\urogroup\.venv\lib\site-packages (from streamlit==1.31.0->-r ../requirements.txt (line 6)) (13.9.4)
# Requirement already satisfied: tenacity<9,>=8.1.0 in c:\users\spdransf\pycharmprojects\urogroup\.venv\lib\site-packages (from streamlit==1.31.0->-r ../requirements.txt (line 6)) (8.5.0)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\spdransf\pycharmprojects\urogroup\.venv\lib\site-packages (from streamlit==1.31.0->-r ../requirements.txt (line 6)) (0.10.2)
# Requirement already satisfied: tzlocal<6,>=1.1 in c:\users\spdransf\pycharmprojects\urogroup\.venv\lib\site-packages (from streamlit==1.31.0->-r ../requirements.txt (line 6)) (5.3.1)
# Requirement already satisfied: validators<1,>=0.2 in c:\users\spdransf\pycharmprojects\urogroup\.venv\lib\site-packages (from streamlit==1.31.0->-r ../requirements.txt (line 6)) (0.35.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\spdransf\pycharmprojects\urogroup\.venv\lib\site-packages (from streamlit==1.31.0->-r ../requirements.txt (line 6)) (3.1.46)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\spdransf\pycharmprojects\urogroup\.venv\lib\site-packages (from streamlit==1.31.0->-r ../requirements.txt (line 6)) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\spdransf\pycharmprojects\urogroup\.venv\lib\site-packages (from streamlit==1.31.0->-r ../requirements.txt (line 6)) (6.5.4)
# Requirement already satisfied: watchdog>=2.1.5 in c:\users\spdransf\pycharmprojects\urogroup\.venv\lib\site-packages (from streamlit==1.31.0->-r ../requirements.txt (line 6)) (6.0.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\spdransf\pycharmprojects\urogroup\.venv\lib\site-packages (from pandas==2.2.0->-r ../requirements.txt (line 7)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\spdransf\pycharmprojects\urogroup\.venv\lib\site-packages (from pandas==2.2.0->-r ../requirements.txt (line 7)) (2025.3)
# Requirement already satisfied: jinja2 in c:\users\spdransf\pycharmprojects\urogroup\.venv\lib\site-packages (from altair<6,>=4.0->streamlit==1.31.0->-r ../requirements.txt (line 6)) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\spdransf\pycharmprojects\urogroup\.venv\lib\site-packages (from altair<6,>=4.0->streamlit==1.31.0->-r ../requirements.txt (line 6)) (4.26.0)
# Requirement already satisfied: narwhals>=1.14.2 in c:\users\spdransf\pycharmprojects\urogroup\.venv\lib\site-packages (from altair<6,>=4.0->streamlit==1.31.0->-r ../requirements.txt (line 6)) (2.15.0)
# Requirement already satisfied: idna>=2.8 in c:\users\spdransf\pycharmprojects\urogroup\.venv\lib\site-packages (from anyio<5,>=3.5.0->openai==1.12.0->-r ../requirements.txt (line 3)) (3.11)
# Requirement already satisfied: colorama in c:\users\spdransf\pycharmprojects\urogroup\.venv\lib\site-packages (from click<9,>=7.0->streamlit==1.31.0->-r ../requirements.txt (line 6)) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\spdransf\pycharmprojects\urogroup\.venv\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit==1.31.0->-r ../requirements.txt (line 6)) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\spdransf\pycharmprojects\urogroup\.venv\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit==1.31.0->-r ../requirements.txt (line 6)) (5.0.2)
# Requirement already satisfied: certifi in c:\users\spdransf\pycharmprojects\urogroup\.venv\lib\site-packages (from httpx<1,>=0.23.0->openai==1.12.0->-r ../requirements.txt (line 3)) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\users\spdransf\pycharmprojects\urogroup\.venv\lib\site-packages (from httpx<1,>=0.23.0->openai==1.12.0->-r ../requirements.txt (line 3)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\spdransf\pycharmprojects\urogroup\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai==1.12.0->-r ../requirements.txt (line 3)) (0.16.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\spdransf\pycharmprojects\urogroup\.venv\lib\site-packages (from importlib-metadata<8,>=1.4->streamlit==1.31.0->-r ../requirements.txt (line 6)) (3.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\spdransf\pycharmprojects\urogroup\.venv\lib\site-packages (from pydantic<3,>=1.9.0->openai==1.12.0->-r ../requirements.txt (line 3)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\spdransf\pycharmprojects\urogroup\.venv\lib\site-packages (from pydantic<3,>=1.9.0->openai==1.12.0->-r ../requirements.txt (line 3)) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\spdransf\pycharmprojects\urogroup\.venv\lib\site-packages (from pydantic<3,>=1.9.0->openai==1.12.0->-r ../requirements.txt (line 3)) (0.4.2)
# Requirement already satisfied: six>=1.5 in c:\users\spdransf\pycharmprojects\urogroup\.venv\lib\site-packages (from python-dateutil<3,>=2.7.3->streamlit==1.31.0->-r ../requirements.txt (line 6)) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\spdransf\pycharmprojects\urogroup\.venv\lib\site-packages (from requests>=2.26.0->tiktoken==0.5.2->-r ../requirements.txt (line 5)) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\spdransf\pycharmprojects\urogroup\.venv\lib\site-packages (from requests>=2.26.0->tiktoken==0.5.2->-r ../requirements.txt (line 5)) (2.6.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\spdransf\pycharmprojects\urogroup\.venv\lib\site-packages (from rich<14,>=10.14.0->streamlit==1.31.0->-r ../requirements.txt (line 6)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\spdransf\pycharmprojects\urogroup\.venv\lib\site-packages (from rich<14,>=10.14.0->streamlit==1.31.0->-r ../requirements.txt (line 6)) (2.19.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\spdransf\pycharmprojects\urogroup\.venv\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit==1.31.0->-r ../requirements.txt (line 6)) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\spdransf\pycharmprojects\urogroup\.venv\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit==1.31.0->-r ../requirements.txt (line 6)) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\spdransf\pycharmprojects\urogroup\.venv\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit==1.31.0->-r ../requirements.txt (line 6)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\spdransf\pycharmprojects\urogroup\.venv\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit==1.31.0->-r ../requirements.txt (line 6)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\users\spdransf\pycharmprojects\urogroup\.venv\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit==1.31.0->-r ../requirements.txt (line 6)) (0.30.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\spdransf\pycharmprojects\urogroup\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit==1.31.0->-r ../requirements.txt (line 6)) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
### load and check connections ###

from dotenv import load_dotenv
import os

load_dotenv('../.env')

## Verify credentials ##
print("✓ Azure OpenAI Endpoint:", os.getenv("AZURE_OPENAI_ENDPOINT"))
print("✓ Azure OpenAI Embedding Endpoint:", os.getenv("AZURE_OPENAI_EMBEDDING_ENDPOINT"))
print("✓ Azure Search Endpoint:", os.getenv("AZURE_SEARCH_ENDPOINT"))
print("\nAll credentials loaded!")
# Out:
# ✓ Azure OpenAI Endpoint: https://sampd-mbgsuu3f-eastus2.cognitiveservices.azure.com/
# ✓ Azure OpenAI Embedding Endpoint: https://crebot.cognitiveservices.azure.com/
# ✓ Azure Search Endpoint: https://crebot-search.search.windows.net
#
# All credentials loaded!

# %%
## process pdfs ##
import sys
sys.path.append('..')

from src.pdf_processor import SOPProcessor

processor = SOPProcessor()
chunks = processor.process_directory("../data")

print(f"\n✓ Processed {len(chunks)} chunks from SOPs")
print("\nSample chunk:")
print("Metadata:", chunks[0]['metadata'])
print("\nContent preview:", chunks[0]['content'][:300], "...")
# Out:
# Processing: 1.01 CRE SOP FDA Form 1572 - Copy.pdf
#   -> Created 1 chunks
# Processing: 1.01 CRE SOP FDA Form 1572.pdf
#   -> Created 1 chunks
# Processing: 1.02 CRE SOP GCP Training - Copy.pdf
#   -> Created 1 chunks
# Processing: 1.02 CRE SOP GCP Training.pdf
#   -> Created 1 chunks
# Processing: 1.03 CRE SOP Internal Audits - Copy.pdf
#   -> Created 1 chunks
# Processing: 1.03 CRE SOP Internal Audits.pdf
#   -> Created 1 chunks
# Processing: 1.04 CRE SOP MSO Billing - Copy.pdf
#   -> Created 1 chunks
# Processing: 1.04 CRE SOP MSO Billing.pdf
#   -> Created 1 chunks
# Processing: 1.05 CRE SOP New Employee - Copy.pdf
#   -> Created 1 chunks
# Processing: 1.05 CRE SOP New Employee.pdf
#   -> Created 1 chunks
# Processing: 1.06 CRE SOP Protocol Training - Copy.pdf
#   -> Created 1 chunks
# Processing: 1.06 CRE SOP Protocol Training.pdf
#   -> Created 1 chunks
# Processing: 1.07 CRE SOP Roles  Responsibilities v1.4 - Copy.pdf
#   -> Created 29 chunks
# Processing: 1.07 CRE SOP Roles  Responsibilities v1.4.pdf
#   -> Created 29 chunks
# Processing: 1.08 CRE SOP Supplies.pdf
#   -> Created 1 chunks
# Processing: 1.09 CRE SOP UAB Addresses_Updated.03.26.2024 - signed.pdf
#   -> Created 6 chunks
# Processing: 1.10 CRE SOP Work Hours Leave Requests Sick Leave Policy v1.2.pdf
#   -> Created 1 chunks
# Processing: 1.11 CRE SOP UAB Hospital Billing.pdf
#   -> Created 1 chunks
# Processing: 1.12 CRE SOP GreenPhire Clincard.pdf
#   -> Created 1 chunks
# Processing: 1.13 CRE SOP CH20 Patient Transport, Parking and Building Security.pdf
#   -> Created 7 chunks
# Processing: 1.15 CRE SOP Ortho Research Fellows. V2.pdf
#   -> Created 8 chunks
# Processing: 1.16 CRE SOP New Investigator.pdf
#   -> Created 12 chunks
# Processing: 1.17 CRE SOP Error Reporting - signed.pdf
#   -> Created 9 chunks
# Processing: 1.18 CRE SOP Monthly Fiscal Analysis Report.pdf
#   -> Created 7 chunks
# Processing: 1.19 CRE SOP Medical Equipment Calibraiton - signed.pdf
#   -> Created 13 chunks
# Processing: 1.20 CRE SOP REDCap Room Reservations at CH20 Clinic.pdf
#   -> Created 7 chunks
# Processing: 1.21 SOP CH20 Research Clinic Rules and Regualtions.pdf
#   -> Created 7 chunks
# Processing: 1.22 CRE SOP Adobe Sign 21 CFR Part 11 Validation.pdf
#   -> Created 10 chunks
# Processing: 1.23 CRE SOP Study Coordinator Team Meetings.pdf
#   -> Created 1 chunks
# Processing: 2.0 CRE SOP Attending an Investigator Meeting.pdf
#   -> Created 1 chunks
# Processing: 2.01 CRE SOP Regulatory Documents.pdf
#   -> Created 1 chunks
# Processing: 2.02 CRE SOP Master Binders - Copy.pdf
#   -> Created 1 chunks
# Processing: 2.02 CRE SOP Master Binders.pdf
#   -> Created 1 chunks
# Processing: 2.04 CRE SOP Site Specific ICF - Copy.pdf
#   -> Created 1 chunks
# Processing: 2.04 CRE SOP Site Specific ICF.pdf
#   -> Created 1 chunks
# Processing: 3.00 CRE SOP Filing Sponsor Correspondence - Copy (2).pdf
#   -> Created 1 chunks
# Processing: 3.00 CRE SOP Filing Sponsor Correspondence - Copy - Copy.pdf
#   -> Created 1 chunks
# Processing: 3.00 CRE SOP Filing Sponsor Correspondence - Copy.pdf
#   -> Created 1 chunks
# Processing: 3.00 CRE SOP Filing Sponsor Correspondence.pdf
#   -> Created 1 chunks
# Processing: 3.01 CRE SOP IND Reporting - Copy.pdf
#   -> Created 1 chunks
# Processing: 3.01 CRE SOP IND Reporting.pdf
#   -> Created 1 chunks
# Processing: 3.02 Informed Consent Process - Copy.pdf
#   -> Created 1 chunks
# Processing: 3.02 Informed Consent Process.pdf
#   -> Created 1 chunks
# Processing: 3.03 CRE SOP Investigational Drug Accountability and Destruction v2 - Copy.pdf
#   -> Created 11 chunks
# Processing: 3.03 CRE SOP Investigational Drug Accountability and Destruction v2.pdf
#   -> Created 11 chunks
# Processing: 3.04 CRE SOP Monitor Visits_v7.0.pdf
#   -> Created 8 chunks
# Processing: 3.07 CRE SOP Source Documentation.pdf
#   -> Created 1 chunks
# Processing: 3.08 CRE SOP Participant Stipend and Reimbursement.pdf
#   -> Created 1 chunks
# Processing: 3.09 CRE SOP Study Drug Transport v3.0.pdf
#   -> Created 9 chunks
# Processing: 3.10 CRE SOP Lab Kit Destruction.pdf
#   -> Created 1 chunks
# Processing: 3.11 CRE SOP Utilizing AdobeSign&Zoom in the Informed Consenting Process.pdf
#   -> Created 11 chunks
# Processing: 3.12 CRE SOP Pre-Screening Research Subjects for COVID.docx.pdf
#   -> Created 8 chunks
# Processing: 3.13 CRE SOP IB Training Documention.pdf
#   -> Created 9 chunks
# Processing: 3.14 CRE SOP IRB Continuing Reviews Final - signed.pdf
#   -> Created 9 chunks
# Processing: 3.15 CRE SOP CITI IRB and GCP Trainingdocx - signed.pdf
#   -> Created 34 chunks
# Processing: 3.16 CRE SOP AE-SAE Reporting_CRE Level.pdf
#   -> Created 7 chunks
# Processing: 4.00 CRE SOP FDA Audits.pdf
#   -> Created 1 chunks
# Processing: 4.01 CRE SOP Long Term Storage v1.2 - Copy.pdf
#   -> Created 5 chunks
# Processing: 4.01 CRE SOP Long Term Storage v1.2.pdf
#   -> Created 5 chunks
# Processing: 4.02 CRE SOP Sponsor Audits.pdf
#   -> Created 1 chunks
# Processing: COVID-19 Screening form (002).pdf
#   -> Created 1 chunks
# Processing: CRE SOP Research Office Move - signed.pdf
#   -> Created 7 chunks
# Processing: Felice Cook Roles and Responsibilities.pdf
#   -> Created 3 chunks
# Processing: Finance and Contracts Team Roles and Responsibilities.pdf
#   -> Created 3 chunks
# Processing: Grants Administrator Roles and Responsibilities.pdf
#   -> Created 2 chunks
# Processing: IRB.POL_.HRP_.071-Prompt-Reporting-Requirements_v4.0_website.pdf
#   -> Created 4 chunks
# Processing: Leigh Powell Roles and Responsibilities.pdf
#   -> Created 3 chunks
# Processing: Patrick Frazier Roles and Responsibilities.pdf
#   -> Created 3 chunks
# Processing: RECOVER Study Visit Completion and Documentation SOP V31Aug2023.pdf
#   -> Created 10 chunks
# Processing: RECOVER Study Visit Completion and Documentation SOP.pdf
#   -> Created 11 chunks
# Processing: Regulatory Coordinator Roles and Responsibilities.pdf
#   -> Created 4 chunks
# Processing: Sarah Houston Roles and Responsibilities.pdf
#   -> Created 3 chunks
# Processing: Study Coordinator Roles and Responsiblities.pdf
#   -> Created 2 chunks
# Processing: Susan Binkley Roles and Responsibilities.pdf
#   -> Created 2 chunks
#
# ✓ Processed 365 chunks from SOPs
#
# Sample chunk:
# Metadata: {'filename': '1.01 CRE SOP FDA Form 1572 - Copy.pdf', 'sop_number': '1.01', 'version': '', 'title': '1.01 CRE SOP FDA Form 1572 - Copy', 'effective_date': '', 'section_type': 'Chunk 1', 'char_count': 0}
#
# Content preview: SOP 1.01: 1.01 CRE SOP FDA Form 1572 - Copy
#
#  ...

# %%
## generate embeddings ##
from src.embeddings import EmbeddingGenerator

generator = EmbeddingGenerator()

### Extract content for embedding ##
contents = [chunk['content'] for chunk in chunks]

### Generate embeddings ##
print("Generating embeddings (this may take a minute)...")
embeddings = generator.generate_batch_embeddings(contents)

print(f"\n✓ Generated {len(embeddings)} embeddings")
print(f"✓ Embedding dimension: {len(embeddings[0])}")
# Out:
# Generating embeddings (this may take a minute)...
# Processed 100/365 embeddings
# Processed 200/365 embeddings
# Processed 300/365 embeddings
# Processed 365/365 embeddings
#
# ✓ Generated 365 embeddings
# ✓ Embedding dimension: 1536

# %%
### create search index ##
from src.search_index import AzureSearchIndexManager

manager = AzureSearchIndexManager()

### Delete existing index if any ##
print("Checking for existing index...")
manager.delete_index()

### Create new index ##
print("\nCreating new index...")
manager.create_index(embedding_dimensions=1536)
# Out:
# Checking for existing index...
# Index 'sop-index' deleted
#
# Creating new index...
# Index 'sop-index' created successfully

# %%
## upload docs ##
import uuid

documents = []
for chunk, embedding in zip(chunks, embeddings):
    doc = {
        "id": str(uuid.uuid4()),
        "content": chunk['content'],
        "sop_number": chunk['metadata']['sop_number'],
        "title": chunk['metadata']['title'],
        "section_type": chunk['metadata']['section_type'],
        "version": chunk['metadata']['version'],
        "filename": chunk['metadata']['filename'],
        "effective_date": chunk['metadata']['effective_date'],
        "content_vector": embedding
    }
    documents.append(doc)

# Upload AZ search ##
print(f"Uploading {len(documents)} documents to Azure Search...")
manager.upload_documents(documents)

print(f"\n✓ Successfully uploaded {len(documents)} documents!")
# Out:
# Uploading 365 documents to Azure Search...
# Uploaded 365 documents
#
# ✓ Successfully uploaded 365 documents!

# %%
### test RAG ##
from src.rag_pipeline import SOPRAGPipeline

pipeline = SOPRAGPipeline()

test_queries = [
    "What is the parking procedure for patients at CH20?",
    "How should informed consent be obtained remotely?",
    "What should I do during a sponsor audit?"
]

for query in test_queries:
    print(f"\n{'='*60}")
    print(f"Question: {query}")
    print('='*60)

    result = pipeline.query(query)

    print(f"\nAnswer:\n{result['answer']}")
    print(f"\nSources:\n" + "\n".join(f"- {s}" for s in result['sources']))
# Out:
# ============================================================
# Question: What is the parking procedure for patients at CH20?
# ============================================================
# Retrieving documents for: What is the parking procedure for patients at CH20?
# Generating answer...
#
# Answer:
# According to SOP 1.13, the parking procedure for patients at CH20 is as follows:
#
# - When scheduling an appointment, provide patients with:
#   - The address, directions, a map to the parking lot, and clinic contact information.
#   - Inform them that the parking lot entrance is on 20th Street.
# - Instruct patients on how to get from the parking lot to the building entrance and tell them to call upon arrival.
# - Inform patients:
#   - They cannot follow anyone into the building and must remain outside until let in by appropriate personnel.
#   - If the front intercom is used, provide instructions:
#     1. Click the Contacts Button.
#     2. Choose the clinic/department for their appointment.
#     3. Choose the same clinic/department again to CALL.
#     4. Someone will answer, verify the appointment, and unlock the door automatically.
# - Verify the patient before buzzing them in and give specific instructions on how to get to the appropriate clinic.
# - After the appointment, provide the patient with the exit code for the parking lot.
# - The Research Coordinator/Nurse must escort all patients out of the building.
#
# **Note:** Never give the parking lot exit code to anyone who is not a CH20 patient.
# (SOP 1.13)
#
# Sources:
# - SOP 1.13: CH20 Patient Transport/Parking and Building Security (Purpose)
# - SOP 1.13: CH20 Patient Transport/Parking and Building Security (Procedures)
# - SOP 1.13: CH20 Patient Transport/Parking and Building Security (Scope)
#
# ============================================================
# Question: How should informed consent be obtained remotely?
# ============================================================
# Retrieving documents for: How should informed consent be obtained remotely?
# Generating answer...
#
# Answer:
# Based on SOP 3.11, informed consent should be obtained remotely as follows:
#
# - Use a HIPAA-approved video conferencing system (e.g., UAB HIPAA-compliant Zoom) or phone.
# - The participant joins a secure meeting with the person obtaining consent.
# - The informed consent form is shared via screen sharing in Zoom.
# - Allow time for the participant to ask questions.
# - If a witness is required, they may join the video conference or phone call.
# - After thorough review and discussion, the consent form is sent to the participant (and witness, if applicable) via UAB Adobe Sign for electronic signature.
# - A signed copy of the informed consent form is sent to the participant and filed in the source chart according to CRE SOP 3.02.
#
# (SOP 3.11 and SOP 3.02)
#
# Sources:
# - SOP 3.02: 3.02 Informed Consent Process (Chunk 1)
# - SOP 3.11: Utilizing DocuSign and Zoom in the Informed Consenting Process (Procedures)
# - SOP 3.11: Utilizing DocuSign and Zoom in the Informed Consenting Process (Procedures)
#
# ============================================================
# Question: What should I do during a sponsor audit?
# ============================================================
# Retrieving documents for: What should I do during a sponsor audit?
# Generating answer...
#
# Answer:
# The provided SOP context does not include specific procedures or instructions regarding what to do during a sponsor audit. For detailed guidance on sponsor audits, please refer to SOP 4.02 - 4.02 CRE SOP Sponsor Audits.
#
# Sources:
# - SOP 4.02: 4.02 CRE SOP Sponsor Audits (Chunk 1)
# - SOP 3.12: Pre-Screening of Rese arch Subjects for COVID -19 (Procedures)
# - SOP 3.12: Pre-Screening of Rese arch Subjects for COVID -19 (References)

# %%
### test interaction ##
query = input("Enter your question: ")
result = pipeline.query(query)

print(f"\n{'='*60}")
print(f"Answer:\n{result['answer']}")
print(f"\n{'='*60}")
print(f"Sources:\n" + "\n".join(f"- {s}" for s in result['sources']))
# Out:
# Retrieving documents for: What all needs to be done for a monitor visit?
#
# Generating answer...
#
# ============================================================
# Answer:
# Based on SOP 3.04 – Monitor Visits (On Site or Remote), the following steps need to be completed for a monitor visit:
#
# **I. Scheduling and Preparation**
# - Provide new monitors with the Monitor Informational Packet before any visit (remote or onsite).
# - Schedule monitoring visits in advance:
#   - Minimum of four (4) weeks for new monitors.
#   - Minimum of three (3) weeks for established monitors.
# - Use the Fillable Monitor Request Form to schedule the visit.
# - Regulatory Coordinator sends a calendar invitation to all regulatory personnel and the Study Coordinator.
# - If EMR access is required, Ronald Prevatt initiates the access request process.
# - Study Coordinator is cc’d on all related correspondence.
# - Study Coordinator secures and reserves a designated workspace for the monitor and notifies the regulatory team of the location.
# - Monitors must submit the IMV (Interim Monitoring Visit) letter to the Study Coordinator at least two (2) weeks prior to the scheduled visit.
# - Monitors must submit a screenshot showing successful EMR (CERNER/IMPACT) access at least one (1) week prior to the visit.
# - If the screenshot is not received, Study Coordinator must follow up; if no response within two (2) business days, the visit is canceled and rescheduled.
# - Over-the-shoulder EMR viewing and printing/certifying EMR source documents are not permitted.
#
# **II. Day(s) of Monitor Visit**
# - Study Coordinator ensures all relevant study documentation is available for review.
# - Study Coordinator is present in the morning to welcome the monitor, assist with room setup, and provide general EMR navigation guidance (not technical troubleshooting).
# - Preferred method of communication is established for the visit.
# - Study Coordinator coordinates queries and follow-ups during the day.
# - If requested, Research Nurse Manager reviews monitoring findings.
# - Exit interview is scheduled at the end of the visit after all documents are reviewed.
# - Monitors are restricted to assigned monitoring room and restrooms; access to other areas requires staff accompaniment.
# - Additional fees apply for non-routine visits accessing the e-regulatory binder outside standard monitoring visits.
#
# **III. Allowable Exceptions**
# - Exceptions to these procedures require prior approval from CRE Executive Leadership.
#
# **Reference:** SOP 3.04 – Monitor Visits (On Site or Remote)
#
# ============================================================
# Sources:
# - SOP 3.04: Monitor Visits  (On Site or Remote) (Details)
# - SOP 3.04: Monitor Visits  (On Site or Remote) (Training)
# - SOP 3.04: Monitor Visits  (On Site or Remote) (Allowable Exceptions)
